# %% [markdown]
# # BeautyfulSoup 네이버 뉴스 기사 스크래핑

# %% [markdown]
# ## 뉴스 기사 스크래핑 함수 정의

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import pandas as pd


def get_news(query, page_num=10):

    news_df= pd.DataFrame(columns=('Title', 'Link', 'Press', 'Datetime', 'Article'))
    idx= 0

    url_query= quote(query)
    url= "https://search.naver.com/search.naver?where=news&sm=nws_hty&query="+ url_query


    for _ in range(0, page_num):

        search_url= urllib.request.urlopen(url).read()
        soup= BeautifulSoup(search_url, 'html.parser')
        links= soup.find_all('dd', {'class': 'txt_inline'})

        for link in links:
            press= link.find('span', {'class': '_sp_each_source'}).get_text()
            news_url= link.find('a').get('href')

            if (news_url== '#'):
                continue
            else:
                news_link= urllib.request.urlopen(news_url).read()
                news_html= BeautifulSoup(news_link, 'html.parser')

                try:
                    title= news_html.find('h3', {'id': 'articleTitle'}).get_text()
                    datetime= news_html.find('span', {'class': 't11'}).get_text()
                    article= news_html.find('div', {'id': 'articleBodyContents'}).get_text()

                    article= article.replace("// flash 오류를 우회하기 위한 함수 추가", "")
                article= article.replace("function _flash_removeCallback() {}", "")
                    article= article.replace("\n", "")
                    article= article.replace("\t", "")
                        

                    news_df.loc[idx]= [title, news_url, press, datetime, article]
                    idx+= 1
                    print('#', end="")
                except:
                    continue

        try:
            next= soup.find('a', {'class': 'next'}).get('href')
            url= "https://search.naver.com/search.naver" + next
        except:
            break

    return news_df

# %% [markdown]
# ## 뉴스 기사 스크래핑 실행

# %%
query= input('검색 질의:')
news_df= get_news(query, 10)
print('Done')
# Out:
# 검색 질의:인공지능
# ###################################Done

# %%
news_df
# Out:
#                                                 Title  ...                                            Article
# 0                  교원그룹-셀바스AI ‘인공지능 기반 디지털 헬스케어’ 업무협약  ...  장동하 교원그룹 기획조정실장(왼쪽)과 곽민철 셀바스AI 대표이사가 업무협약 후 기념...
# 1                           "인공지능으로 '자폐'증상·심각도 예측 가능"  ...  뇌영상 빅데이터를 활용한 딥러닝(Deep Learning)으로 자폐 스펙트럼 장애(...
# 2                             인공지능, 소화기내시경도 대체할 수 있을까  ...  국내 의료 AI, 데이터 많은 이미지 기반 진단 분야 발전 강세교육, 법적 문제 등...
# 3                        교원그룹, 인공지능 기반 디지털 헬스케어 구축 앞장  ...  셀바스AI와 손잡고 셀비 체크업과 연계한 생활 맞춤 솔루션 개발[아이뉴스24 장유미...
# 4                         현대해상, 인공지능 적용 보험사기 예측시스템 개발  ...  ◆…현대해상이 보험사기에 적극 대응하고자 인공지능(AI)을 적용한 보험사기 예측시스...
# 5                     구직자 48.1% "인공지능 면접이 사람보다 더 공정해"  ...  면접 선호도는 대면면접(46.8%)이 AI면접(16.2%) 보다 높아 구직자 40....
# 6           [신간안내]4차 산업혁명을 시작하는 AI 기술… '헬스케어 인공지능' 출간  ...  헬스케어 인공지능의 개념·기술, 디바이스, 진단·치료 등 활용 분야를 사례 중심으로...
# 7                              제이엘케이, 암 분야 인공지능 특허 출원  ...  제이엘케이는 암 영역에 대한 딥러닝 모델 학습 장치 및 방법에 관한 특허를 출원 및...
# 8                인공지능 기반 자율방역 로봇 등 40개 개발과제에 370억원 지원  ...  과기부 '비대면 비즈니스 디지털혁신 기술개발' 과제 40개 선정(서울=연합뉴스) 정...
# 9                   ‘인공지능 보스’에 열광하는 유저들…게임업계 판도 바꾼 AI  ...  -[스페셜리포트 ①] 기획부터 조작까지 ‘AI 혁신’ 이룬 3N(엔씨·넥슨·넷마블)...
# 10                      국립국어원, 인공지능 학습용 한국어 자료 대규모 공개  ...  국립국어원 로고[파이낸셜뉴스] 국립국어원은 인공지능의 한국어 처리 능력 향상에 필수...
# 11                경기창조경제혁신센터 '인공지능 투자유치 지원 IR DAY' 개최  ...  2020 K-Champ Forum; 인공지능 투자유치 지원 IR DAY. 제공|경기...
# 12                 아카, 김포 분진중과 인공지능 학습 로봇 '뮤지오' 공급 계약  ...  ▲ 아카에이아이(아카)는 경기도 김포 분진 중학교와 인공지능(AI) 학습 로봇 뮤지...
# 13                          언택트 시대 맞춰 인공지능 콜센터 빠르게 확대  ...  AI 실시간 상담도우미 시스템 및 고객상담 챗봇 화면 예시 (NH농협은행) 인공지능...
# 14                동원그룹, '인공지능' 기술 활용한 新 물류 플렛폼 개발 나선다  ...  KT와 손잡고 'AI 원팀' 참여27일 서울 종로구 KT 광화문빌딩에서 열린 '대한...
# 15                    케플러 미확인 자료서 행성 50개 확인…인공지능 첫 성과  ...  가짜 신호 가려내는 기계학습 알고리즘 구축 "쉽고, 빠르게 확인" 케플러 우주망원경...
# 16                    광문각, 김효관 폴리텍대 교수 '빅데이터＆인공지능' 출간  ...  ▲ 출판사 광문각은 지난 18일 김효관 한국폴리텍대 서울강서캠퍼스 스마트금융과 교수...
# 17                  현직 교사 5000명 '인공지능 융합교육 전문교사'로 키운다  ...  "수업에서 인공지능을 활용하는 역량이 갈수록 중요해질 것"유은혜 부총리 겸 교육부 ...
# 18                       제이엘케이, 터키서 인공지능 의료기기 7건 품목허가  ...  제이엘케이는 인공지능 기반 폐 컴퓨터단층촬영(CT) 영상 진단보조소프트웨어 등 7개...
# 19               금성출판사, 인공 지능 교과서 '인공 지능과 피지컬 컴퓨팅' 출간  ...  금성출판사가 인공 지능 전문 교과서 '인공 지능과 피지컬 컴퓨팅'을 출간하고, 인천...
# 20                     타임소프트, 인공지능 빅데이터 플랫폼 솔루션 사업 공략  ...  (지디넷코리아=남혁우  기자)국내외 지능형 빅데이터와 분석 비즈니스 시장이 가장 중...
# 21                         한국인공지능학회, 여수 학술대회 온라인으로 전환  ...  [한국인공지능학회 홈페이지 캡처. 재판매 및 DB 금지]     (대전=연합뉴스) ...
# 22                          국립국어원, 인공지능 한국어 학습용 자료 공개  ...  일상 대화, 웹, 신문, 서적 등 한국어 빅데이터 13종 18억 어절‘모두의 말뭉치...
# 23    [2021학년도 대학 수시모집] 서울과기대, 인공지능응용학과 신입생 4년 전액 장학금  ...  [서울경제] 서울과학기술대는 2021학년도 수시모집으로 1,525명을 선발한다. 전...
# 24                              백악관 "인공지능·양자기술 1조 투자"  ...  백악관 홈페이지미국 연방정부가 국가안보를 위해 인공지능(AI)과 양자컴퓨팅 등에 1...
# 25                    와이즈넛, 대학가 언택트 교육서비스로 인공지능 챗봇 확대  ...  국내 최다 인공지능 챗봇 솔루션 구축 노하우 집약끊임없는 코로나19 사태로 수도권 ...
# 26              [김정호의 AI시대의 전략] 양자역학과 인공지능의 공통점은 불확실성  ...  나노미터(10억분의 1m) 크기 원자나 분자 영역에서 일어나는 미시 세계 물리적인 ...
# 27  [윤희영의 News English] F16 탑건과 인공지능 조종사의 공중전 대결 :...  ...  이세돌 9단과 '알파고'의 바둑 대결은 1대4로 인공지능(AI·Artificial ...
# 28                      가천대학교, 국내 1호 인공지능학부…150명으로 확대  ...  2021학년도 대입 수시가천대 캠퍼스 전경가천대(입학처장 이재희·사진)는 2021학...
# 29                           '한국 오는 해외확진자' 인공지능이 예측한다  ...  24일 공군 공중급유기 'KC-330'를 타고 인천공항에 도착한 이라크 파견 근로자...
# 30                   중기부, 아마존·MS 등 손 잡고 인공지능 스타트업 키운다  ...  일러스트=김성규중소벤처기업부가 아마존·마이크로소프트 등과 손잡고 인공지능(AI) 스...
# 31                 서울과학기술대학교, '인공지능응용학과' 최대 9년 전액 장학금  ...  2021학년도 대입 수시서울과학기술대 다산관 전경서울과학기술대(입학관리본부장 신현상...
# 32                        미세조직 데이터만으로 재료강도 예측 인공지능 개발  ...  경상대 성효경, 한동대 정임두, 포스텍 박성진 교수 연구팀[윤성효 기자]      ...
# 33                        광주시, 인공지능 기업과 협약…합작사 설립도 추진  ...  광주형 인공지능 기본 조성 협약[광주시 제공.재판매 및 DB 금지](광주=연합뉴스)...
# 34               ‘인공지능응용학과’ 신설…신입생에 최대 9년까지 전액 장학금 지급  ...  서울과학기술대학교4차 산업혁명 시대 맞아…특성화된 미래인재 집중 육성서울과기대 강점...
#
# [35 rows x 5 columns]

# %%
news_df['Article']
# Out:
# 0     장동하 교원그룹 기획조정실장(왼쪽)과 곽민철 셀바스AI 대표이사가 업무협약 후 기념...
# 1     뇌영상 빅데이터를 활용한 딥러닝(Deep Learning)으로 자폐 스펙트럼 장애(...
# 2     국내 의료 AI, 데이터 많은 이미지 기반 진단 분야 발전 강세교육, 법적 문제 등...
# 3     셀바스AI와 손잡고 셀비 체크업과 연계한 생활 맞춤 솔루션 개발[아이뉴스24 장유미...
# 4     ◆…현대해상이 보험사기에 적극 대응하고자 인공지능(AI)을 적용한 보험사기 예측시스...
# 5     면접 선호도는 대면면접(46.8%)이 AI면접(16.2%) 보다 높아 구직자 40....
# 6     헬스케어 인공지능의 개념·기술, 디바이스, 진단·치료 등 활용 분야를 사례 중심으로...
# 7     제이엘케이는 암 영역에 대한 딥러닝 모델 학습 장치 및 방법에 관한 특허를 출원 및...
# 8     과기부 '비대면 비즈니스 디지털혁신 기술개발' 과제 40개 선정(서울=연합뉴스) 정...
# 9     -[스페셜리포트 ①] 기획부터 조작까지 ‘AI 혁신’ 이룬 3N(엔씨·넥슨·넷마블)...
# 10    국립국어원 로고[파이낸셜뉴스] 국립국어원은 인공지능의 한국어 처리 능력 향상에 필수...
# 11    2020 K-Champ Forum; 인공지능 투자유치 지원 IR DAY. 제공|경기...
# 12    ▲ 아카에이아이(아카)는 경기도 김포 분진 중학교와 인공지능(AI) 학습 로봇 뮤지...
# 13    AI 실시간 상담도우미 시스템 및 고객상담 챗봇 화면 예시 (NH농협은행) 인공지능...
# 14    KT와 손잡고 'AI 원팀' 참여27일 서울 종로구 KT 광화문빌딩에서 열린 '대한...
# 15    가짜 신호 가려내는 기계학습 알고리즘 구축 "쉽고, 빠르게 확인" 케플러 우주망원경...
# 16    ▲ 출판사 광문각은 지난 18일 김효관 한국폴리텍대 서울강서캠퍼스 스마트금융과 교수...
# 17    "수업에서 인공지능을 활용하는 역량이 갈수록 중요해질 것"유은혜 부총리 겸 교육부 ...
# 18    제이엘케이는 인공지능 기반 폐 컴퓨터단층촬영(CT) 영상 진단보조소프트웨어 등 7개...
# 19    금성출판사가 인공 지능 전문 교과서 '인공 지능과 피지컬 컴퓨팅'을 출간하고, 인천...
# 20    (지디넷코리아=남혁우  기자)국내외 지능형 빅데이터와 분석 비즈니스 시장이 가장 중...
# 21    [한국인공지능학회 홈페이지 캡처. 재판매 및 DB 금지]     (대전=연합뉴스) ...
# 22    일상 대화, 웹, 신문, 서적 등 한국어 빅데이터 13종 18억 어절‘모두의 말뭉치...
# 23    [서울경제] 서울과학기술대는 2021학년도 수시모집으로 1,525명을 선발한다. 전...
# 24    백악관 홈페이지미국 연방정부가 국가안보를 위해 인공지능(AI)과 양자컴퓨팅 등에 1...
# 25    국내 최다 인공지능 챗봇 솔루션 구축 노하우 집약끊임없는 코로나19 사태로 수도권 ...
# 26    나노미터(10억분의 1m) 크기 원자나 분자 영역에서 일어나는 미시 세계 물리적인 ...
# 27    이세돌 9단과 '알파고'의 바둑 대결은 1대4로 인공지능(AI·Artificial ...
# 28    2021학년도 대입 수시가천대 캠퍼스 전경가천대(입학처장 이재희·사진)는 2021학...
# 29    24일 공군 공중급유기 'KC-330'를 타고 인천공항에 도착한 이라크 파견 근로자...
# 30    일러스트=김성규중소벤처기업부가 아마존·마이크로소프트 등과 손잡고 인공지능(AI) 스...
# 31    2021학년도 대입 수시서울과학기술대 다산관 전경서울과학기술대(입학관리본부장 신현상...
# 32    경상대 성효경, 한동대 정임두, 포스텍 박성진 교수 연구팀[윤성효 기자]      ...
# 33    광주형 인공지능 기본 조성 협약[광주시 제공.재판매 및 DB 금지](광주=연합뉴스)...
# 34    서울과학기술대학교4차 산업혁명 시대 맞아…특성화된 미래인재 집중 육성서울과기대 강점...
# Name: Article, dtype: object
